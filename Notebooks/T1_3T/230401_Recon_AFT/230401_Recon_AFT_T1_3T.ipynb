# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/deepLGitHub/
from pathlib import Path
# !pip install -r requirements_versioned_updated.txt

# %%
filename = Path('saved_model/T1_3T/230401_Recon_AFT/weights.pt')
filename.touch(exist_ok=True)

# %%
# !python scripts/230401_Recon_AFT/train.py --data_csv data_T1_3T.csv --save_dir saved_model/T1_3T/230401_Recon_AFT --loss_func mse_loss --device cuda:0 --resume

# %%
# !python scripts/230401_Recon_AFT/eval.py --data_csv data_T1_3T.csv --save_dir saved_model/T1_3T/230401_Recon_AFT --device cuda:0
