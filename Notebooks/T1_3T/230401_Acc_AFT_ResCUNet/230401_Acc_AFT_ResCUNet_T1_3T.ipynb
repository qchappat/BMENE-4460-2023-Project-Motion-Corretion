# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/deepLGitHub/
from pathlib import Path
# !pip install -r requirements_versioned_updated.txt

# %%
filename = Path('saved_model/T1_3T/230401_Acc_AFT_ResCUNet/weights.pt')
filename.touch(exist_ok=True)

# %%
# !python scripts/230401_Acc_AFT_ResCUNet/train.py --data_csv data_T1_3T.csv --save_dir saved_model/T1_3T/230401_Acc_AFT_ResCUNet --AFT saved_model/T1_3T/230401_Recon_AFT/weights.pt --ResCUNet saved_model/T1_3T/230401_Acc_ResCUNet_i2i/weights.pt --loss_func mse_loss --json_path data/data_to_original_dict.json --device cuda:0

# %%
# !python scripts/230401_Acc_AFT_ResCUNet/eval.py --data_csv data_T1_3T.csv --save_dir saved_model/T1_3T/230401_Acc_AFT_ResCUNet --json_path data/data_to_original_dict.json --device cuda:0
