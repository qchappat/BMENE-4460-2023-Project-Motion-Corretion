# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/deepLGitHub/
from pathlib import Path
# !pip install -r requirements_versioned_updated.txt

# %%
filename = Path('saved_model/T2_3T/230401_Recon_AFT/weights.pt')
filename.touch(exist_ok=True)

# %%
# !python scripts/230401_Recon_AFT/train.py --data_csv data_T2_3T.csv --save_dir saved_model/T2_3T/230401_Recon_AFT --loss_func mse_loss --device cuda:0
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% 0/840 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...

# %%
# !python scripts/230401_Recon_AFT/eval.py --data_csv data_T2_3T.csv --save_dir saved_model/T2_3T/230401_Recon_AFT --device cuda:0
# Out:
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1ElJypKGXsUCZSK1mnAV4rmzxE_R0zymD/deepLGitHub/scripts/230401_Recon_AFT/eval.py", line 110, in <module>
#     model = setup_model(save_dir, args)
#   File "/content/drive/.shortcut-targets-by-id/1ElJypKGXsUCZSK1mnAV4rmzxE_R0zymD/deepLGitHub/scripts/230401_Recon_AFT/eval.py", line 48, in setup_model
#     model.load_state_dict(torch.load(save_dir / 'weights.pt'))
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 795, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 1002, in _legacy_load
#     magic_number = pickle_module.load(f, **pickle_load_args)
# EOFError: Ran out of input
