# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/deepLGitHub/
from pathlib import Path
# !pip install -r requirements_versioned_updated.txt

# %%
filename = Path('saved_model/Mix_T1_3T_T2_15T/230401_Recon_AFT/weights.pt')
filename.touch(exist_ok=True)

# %%
# !python scripts/230401_Recon_AFT/train.py --data_csv data_mix_T1_3T_T2_15T.csv --save_dir saved_model/Mix_T1_3T_T2_15T/230401_Recon_AFT --loss_func mse_loss --device cuda:0

# %%
# !python scripts/230401_Recon_AFT/eval.py --data_csv data_mix_T1_3T_T2_15T.csv --save_dir saved_model/Mix_T1_3T_T2_15T/230401_Recon_AFT --device cuda:0
